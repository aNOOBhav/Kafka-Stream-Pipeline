# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
pip install s3fs
# Out:
# Requirement already satisfied: s3fs in c:\python\python37\lib\site-packages (2023.1.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: aiobotocore~=2.4.2 in c:\python\python37\lib\site-packages (from s3fs) (2.4.2)
# Requirement already satisfied: fsspec==2023.1.0 in c:\python\python37\lib\site-packages (from s3fs) (2023.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\python\python37\lib\site-packages (from s3fs) (3.8.4)
# Requirement already satisfied: botocore<1.27.60,>=1.27.59 in c:\python\python37\lib\site-packages (from aiobotocore~=2.4.2->s3fs) (1.27.59)
# Requirement already satisfied: wrapt>=1.10.10 in c:\python\python37\lib\site-packages (from aiobotocore~=2.4.2->s3fs) (1.15.0)
# Requirement already satisfied: aioitertools>=0.5.1 in c:\python\python37\lib\site-packages (from aiobotocore~=2.4.2->s3fs) (0.11.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\python\python37\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\python\python37\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\python\python37\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\python\python37\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\python\python37\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\python\python37\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\python\python37\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (1.3.1)
# Requirement already satisfied: asynctest==0.13.0 in c:\python\python37\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (0.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\python\python37\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (4.6.3)
# Requirement already satisfied: importlib-metadata in c:\python\python37\lib\site-packages (from attrs>=17.3.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (6.6.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\python\python37\lib\site-packages (from botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.2->s3fs) (1.0.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\python\python37\lib\site-packages (from botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.2->s3fs) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\python\python37\lib\site-packages (from botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.2->s3fs) (1.26.16)
# Requirement already satisfied: idna>=2.0 in c:\python\python37\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.4)
# Requirement already satisfied: six>=1.5 in c:\python\python37\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.27.60,>=1.27.59->aiobotocore~=2.4.2->s3fs) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in c:\python\python37\lib\site-packages (from importlib-metadata->attrs>=17.3.0->aiohttp!=4.0.0a0,!=4.0.0a1->s3fs) (3.15.0)

# %%
consumer = KafkaConsumer(
    'stockmarket-project-1',
     bootstrap_servers=[':9092'], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
for c in consumer:
    print(c.value)
# Out:
# {'Index': 'GDAXI', 'Date': '1995-01-20', 'Open': 2072.959961, 'High': 2072.959961, 'Low': 2048.75, 'Close': 2050.860107, 'Adj Close': 2050.860107, 'Volume': 0.0, 'CloseUSD': 2502.04933054}
# {'Index': 'N100', 'Date': '2009-07-08', 'Open': 524.210022, 'High': 526.0, 'Low': 518.97998, 'Close': 520.219971, 'Adj Close': 520.219971, 'Volume': 251771800.0, 'CloseUSD': 634.6683646199998}
# {'Index': 'N100', 'Date': '2004-02-25', 'Open': 635.099976, 'High': 637.02002, 'Low': 631.419983, 'Close': 635.630005, 'Adj Close': 635.630005, 'Volume': 0.0, 'CloseUSD': 775.4686061000001}
# {'Index': 'NYA', 'Date': '1991-05-13', 'Open': 2181.149902, 'High': 2181.149902, 'Low': 2181.149902, 'Close': 2181.149902, 'Adj Close': 2181.149902, 'Volume': 0.0, 'CloseUSD': 2181.149902}
# {'Index': 'N100', 'Date': '2013-04-30', 'Open': 729.289978, 'High': 729.919983, 'Low': 723.919983, 'Close': 726.8099980000001, 'Adj Close': 726.8099980000001, 'Volume': 275976200.0, 'CloseUSD': 886.7081975599998}
# {'Index': '000001.SS', 'Date': '1998-09-10', 'Open': 1194.875, 'High': 1219.795044, 'Low': 1194.11499, 'Close': 1213.67395, 'Adj Close': 1213.67395, 'Volume': 0.0, 'CloseUSD': 194.187832}
# {'Index': 'NYA', 'Date': '1977-07-05', 'Open': 580.710022, 'High': 580.710022, 'Low': 580.710022, 'Close': 580.710022, 'Adj Close': 580.710022, 'Volume': 0.0, 'CloseUSD': 580.710022}
# {'Index': 'IXIC', 'Date': '2001-06-22', 'Open': 2062.0, 'High': 2074.830078, 'Low': 2028.069946, 'Close': 2034.839966, 'Adj Close': 2034.839966, 'Volume': 1714580000.0, 'CloseUSD': 2034.839966}
# {'Index': 'NYA', 'Date': '1975-06-24', 'Open': 531.650024, 'High': 531.650024, 'Low': 531.650024, 'Close': 531.650024, 'Adj Close': 531.650024, 'Volume': 0.0, 'CloseUSD': 531.650024}
# {'Index': 'N100', 'Date': '2016-12-01', 'Open': 883.340027, 'High': 884.669983, 'Low': 875.6400150000001, 'Close': 877.6099849999999, 'Adj Close': 877.6099849999999, 'Volume': 246165400.0, 'CloseUSD': 1070.6841817}
# {'Index': 'NYA', 'Date': '2010-03-24', 'Open': 7478.72998, 'High': 7478.72998, 'Low': 7398.419922, 'Close': 7408.160156, 'Adj Close': 7408.160156, 'Volume': 4705750000.0, 'CloseUSD': 7408.160156}
# {'Index': 'N225', 'Date': '1975-12-09', 'Open': 4233.02002, 'High': 4233.02002, 'Low': 4233.02002, 'Close': 4233.02002, 'Adj Close': 4233.02002, 'Volume': 0.0, 'CloseUSD': 42.3302002}
# {'Index': 'NYA', 'Date': '1991-11-25', 'Open': 2194.790039, 'High': 2194.790039, 'Low': 2194.790039, 'Close': 2194.790039, 'Adj Close': 2194.790039, 'Volume': 0.0, 'CloseUSD': 2194.790039}
# {'Index': '000001.SS', 'Date': '2010-10-13', 'Open': 2842.137939, 'High': 2862.034912, 'Low': 2826.220947, 'Close': 2861.361084, 'Adj Close': 2861.361084, 'Volume': 185200.0, 'CloseUSD': 457.81777344000005}
# {'Index': 'SSMI', 'Date': '2005-08-09', 'Open': 6624.899902, 'High': 6644.0, 'Low': 6609.0, 'Close': 6638.899902, 'Adj Close': 6638.899902, 'Volume': 35572800.0, 'CloseUSD': 7369.178891220001}
# {'Index': 'GDAXI', 'Date': '2019-10-10', 'Open': 12082.88965, 'High': 12202.70996, 'Low': 12029.45996, 'Close': 12164.2002, 'Adj Close': 12164.2002, 'Volume': 88437900.0, 'CloseUSD': 14840.324244}
# {'Index': '000001.SS', 'Date': '2018-09-26', 'Open': 2785.316895, 'High': 2827.341064, 'Low': 2783.342041, 'Close': 2806.8129879999997, 'Adj Close': 2806.8129879999997, 'Volume': 139600.0, 'CloseUSD': 449.09007808}
# {'Index': '000001.SS', 'Date': '2005-03-01', 'Open': 1305.249023, 'High': 1308.758057, 'Low': 1295.641968, 'Close': 1303.411987, 'Adj Close': 1303.411987, 'Volume': 14000.0, 'CloseUSD': 208.54591792}
# {'Index': 'HSI', 'Date': '1995-12-28', 'Open': 9950.900391, 'High': 9999.099609, 'Low': 9873.799805, 'Close': 9998.200195, 'Adj Close': 9998.200195, 'Volume': 0.0, 'CloseUSD': 1299.76602535}
# {'Index': 'N225', 'Date': '2016-11-18', 'Open': 18024.21094, 'High': 18043.7207, 'Low': 17967.41016, 'Close': 17967.41016, 'Adj Close': 17967.41016, 'Volume': 166800000.0, 'CloseUSD': 179.67410159999997}
# {'Index': 'NYA', 'Date': '2002-05-06', 'Open': 6002.5, 'High': 6002.5, 'Low': 6002.5, 'Close': 6002.5, 'Adj Close': 6002.5, 'Volume': 1122600000.0, 'CloseUSD': 6002.5}
# {'Index': 'N225', 'Date': '1966-06-23', 'Open': 1504.140015, 'High': 1504.140015, 'Low': 1504.140015, 'Close': 1504.140015, 'Adj Close': 1504.140015, 'Volume': 0.0, 'CloseUSD': 15.04140015}
# {'Index': '399001.SZ', 'Date': '2019-05-24', 'Open': 8788.169922, 'High': 8880.80957, 'Low': 8745.599609, 'Close': 8776.769531, 'Adj Close': 8776.769531, 'Volume': 93000.0, 'CloseUSD': 1404.28312496}
# {'Index': 'N225', 'Date': '2012-11-29', 'Open': 9370.290039, 'High': 9412.080078, 'Low': 9350.400391, 'Close': 9400.879883, 'Adj Close': 9400.879883, 'Volume': 113300000.0, 'CloseUSD': 94.00879883}
# {'Index': '000001.SS', 'Date': '2006-04-26', 'Open': 1399.067993, 'High': 1426.625977, 'Low': 1397.348999, 'Close': 1417.477051, 'Adj Close': 1417.477051, 'Volume': 48400.0, 'CloseUSD': 226.79632816000003}
# {'Index': 'N225', 'Date': '1999-01-05', 'Open': 13437.03027, 'High': 13437.03027, 'Low': 13122.61035, 'Close': 13232.74023, 'Adj Close': 13232.74023, 'Volume': 0.0, 'CloseUSD': 132.32740230000002}
# {'Index': 'IXIC', 'Date': '1994-03-02', 'Open': 773.01001, 'High': 783.52002, 'Low': 772.030029, 'Close': 783.469971, 'Adj Close': 783.469971, 'Volume': 326640000.0, 'CloseUSD': 783.469971}
# {'Index': 'TWII', 'Date': '2005-12-19', 'Open': 6386.359863000001, 'High': 6439.200195, 'Low': 6374.490234000001, 'Close': 6431.419922, 'Adj Close': 6431.395508, 'Volume': 4477000.0, 'CloseUSD': 257.25679688}
# {'Index': 'GSPTSE', 'Date': '2010-12-14', 'Open': 13313.90039, 'High': 13328.40039, 'Low': 13241.7002, 'Close': 13280.09961, 'Adj Close': 13280.09961, 'Volume': 21057720000.0, 'CloseUSD': 11022.482676299998}
# {'Index': 'N225', 'Date': '1967-12-18', 'Open': 1259.569946, 'High': 1259.569946, 'Low': 1259.569946, 'Close': 1259.569946, 'Adj Close': 1259.569946, 'Volume': 0.0, 'CloseUSD': 12.59569946}
# {'Index': 'HSI', 'Date': '1994-02-18', 'Open': 10877.799809999999, 'High': 10905.59961, 'Low': 10729.299809999999, 'Close': 10825.90039, 'Adj Close': 10825.90039, 'Volume': 0.0, 'CloseUSD': 1407.3670507000004}
# {'Index': 'GSPTSE', 'Date': '2005-03-01', 'Open': 9701.200195, 'High': 9757.0, 'Low': 9668.299805, 'Close': 9728.0, 'Adj Close': 9728.0, 'Volume': 16792960000.0, 'CloseUSD': 8074.24}
# {'Index': 'N100', 'Date': '2006-07-14', 'Open': 823.450012, 'High': 829.169983, 'Low': 819.710022, 'Close': 819.710022, 'Adj Close': 819.710022, 'Volume': 227200700.0, 'CloseUSD': 1000.04622684}
# {'Index': 'IXIC', 'Date': '2017-10-19', 'Open': 6583.700195, 'High': 6605.290039, 'Low': 6558.529785, 'Close': 6605.069824, 'Adj Close': 6605.069824, 'Volume': 1823860000.0, 'CloseUSD': 6605.069824}
# {'Index': '000001.SS', 'Date': '2017-11-10', 'Open': 3423.1850590000004, 'High': 3438.7919920000004, 'Low': 3414.329102, 'Close': 3432.673096, 'Adj Close': 3432.673096, 'Volume': 189300.0, 'CloseUSD': 549.22769536}
# {'Index': 'GSPTSE', 'Date': '1994-06-02', 'Open': 4301.899902, 'High': 4302.0, 'Low': 4274.700195, 'Close': 4280.600098, 'Adj Close': 4280.600098, 'Volume': 54160000.0, 'CloseUSD': 3552.89808134}
# {'Index': 'HSI', 'Date': '1993-06-11', 'Open': 7262.100098000001, 'High': 7287.899901999999, 'Low': 7247.899901999999, 'Close': 7266.700195, 'Adj Close': 7266.700195, 'Volume': 0.0, 'CloseUSD': 944.67102535}
# {'Index': 'GSPTSE', 'Date': '1992-11-23', 'Open': 3263.899902, 'High': 3263.899902, 'Low': 3250.300049, 'Close': 3258.300049, 'Adj Close': 3258.300049, 'Volume': 32310000.0, 'CloseUSD': 2704.38904067}
# {'Index': '399001.SZ', 'Date': '2008-10-10', 'Open': 6482.189941, 'High': 6500.740234000001, 'Low': 6345.799805, 'Close': 6385.350098, 'Adj Close': 6385.278809, 'Volume': 50900.0, 'CloseUSD': 1021.65601568}
# {'Index': 'GDAXI', 'Date': '1997-02-25', 'Open': 3199.040039, 'High': 3238.97998, 'Low': 3199.040039, 'Close': 3233.340088, 'Adj Close': 3233.340088, 'Volume': 0.0, 'CloseUSD': 3944.67490736}
# {'Index': 'N225', 'Date': '2011-04-14', 'Open': 9579.790039, 'High': 9676.969727, 'Low': 9553.75, 'Close': 9653.919922, 'Adj Close': 9653.919922, 'Volume': 153100000.0, 'CloseUSD': 96.53919922}
# {'Index': 'GDAXI', 'Date': '2008-02-29', 'Open': 6847.899901999999, 'High': 6864.689941, 'Low': 6698.549805, 'Close': 6748.129883, 'Adj Close': 6748.129883, 'Volume': 185672300.0, 'CloseUSD': 8232.71845726}
# {'Index': '000001.SS', 'Date': '1998-05-28', 'Open': 1402.8530269999999, 'High': 1405.5820310000001, 'Low': 1392.900024, 'Close': 1397.89502, 'Adj Close': 1397.89502, 'Volume': 0.0, 'CloseUSD': 223.66320319999997}
# {'Index': 'N225', 'Date': '2004-03-01', 'Open': 11112.67969, 'High': 11329.0, 'Low': 11096.67969, 'Close': 11271.12012, 'Adj Close': 11271.12012, 'Volume': 106900000.0, 'CloseUSD': 112.7112012}
# {'Index': 'N225', 'Date': '1984-02-17', 'Open': 9925.070313, 'High': 9925.070313, 'Low': 9925.070313, 'Close': 9925.070313, 'Adj Close': 9925.070313, 'Volume': 0.0, 'CloseUSD': 99.25070313}
# {'Index': 'N100', 'Date': '2004-01-28', 'Open': 629.5, 'High': 634.919983, 'Low': 629.3099980000001, 'Close': 634.179993, 'Adj Close': 634.179993, 'Volume': 0.0, 'CloseUSD': 773.69959146}
# {'Index': 'IXIC', 'Date': '1991-10-31', 'Open': 541.789978, 'High': 543.01001, 'Low': 540.960022, 'Close': 542.97998, 'Adj Close': 542.97998, 'Volume': 228520000.0, 'CloseUSD': 542.97998}
# {'Index': 'IXIC', 'Date': '1985-06-17', 'Open': 287.5, 'High': 288.100006, 'Low': 286.899994, 'Close': 287.399994, 'Adj Close': 287.399994, 'Volume': 60260000.0, 'CloseUSD': 287.399994}
# {'Index': 'GSPTSE', 'Date': '1985-12-10', 'Open': 2862.0, 'High': 2862.0, 'Low': 2851.899902, 'Close': 2858.699951, 'Adj Close': 2851.44043, 'Volume': 21080000.0, 'CloseUSD': 2372.72095933}
# {'Index': 'GDAXI', 'Date': '1995-05-22', 'Open': 2069.360107, 'High': 2097.350098, 'Low': 2068.199951, 'Close': 2096.8701170000004, 'Adj Close': 2096.8701170000004, 'Volume': 0.0, 'CloseUSD': 2558.18154274}
# {'Index': 'IXIC', 'Date': '1999-08-11', 'Open': 2532.540039, 'High': 2565.149902, 'Low': 2490.110107, 'Close': 2564.97998, 'Adj Close': 2564.97998, 'Volume': 911460000.0, 'CloseUSD': 2564.97998}
# {'Index': 'TWII', 'Date': '2006-06-06', 'Open': 6684.580078, 'High': 6738.779785, 'Low': 6621.169922, 'Close': 6730.27002, 'Adj Close': 6730.244140999999, 'Volume': 3033000.0, 'CloseUSD': 269.2108008}
# {'Index': 'SSMI', 'Date': '2003-05-28', 'Open': 4621.799805, 'High': 4671.799805, 'Low': 4616.5, 'Close': 4664.799805, 'Adj Close': 4664.799805, 'Volume': 55948000.0, 'CloseUSD': 5177.92778355}
# {'Index': 'SSMI', 'Date': '1990-11-22', 'Open': 1400.0, 'High': 1401.400024, 'Low': 1384.5, 'Close': 1388.800049, 'Adj Close': 1388.800049, 'Volume': 0.0, 'CloseUSD': 1541.56805439}
# {'Index': 'N225', 'Date': '2003-01-24', 'Open': 8779.44043, 'High': 8825.669922, 'Low': 8701.320313, 'Close': 8731.650391, 'Adj Close': 8731.650391, 'Volume': 77300000.0, 'CloseUSD': 87.31650391}
# {'Index': 'GSPTSE', 'Date': '2017-04-11', 'Open': 15732.90039, 'High': 15738.299809999999, 'Low': 15604.09961, 'Close': 15727.09961, 'Adj Close': 15727.09961, 'Volume': 22127770000.0, 'CloseUSD': 13053.492676299997}
# {'Index': 'N225', 'Date': '1974-11-29', 'Open': 3927.48999, 'High': 3927.48999, 'Low': 3927.48999, 'Close': 3927.48999, 'Adj Close': 3927.48999, 'Volume': 0.0, 'CloseUSD': 39.2748999}
# {'Index': 'IXIC', 'Date': '1984-07-27', 'Open': 229.30000299999998, 'High': 229.30000299999998, 'Low': 229.30000299999998, 'Close': 229.30000299999998, 'Adj Close': 229.30000299999998, 'Volume': 0.0, 'CloseUSD': 229.30000299999998}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15200\2861557713.py in <module>
# ----> 1 for c in consumer:
#       2     print(c.value)
#
# c:\python\python37\lib\site-packages\kafka\consumer\group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# c:\python\python37\lib\site-packages\kafka\consumer\group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# c:\python\python37\lib\site-packages\kafka\consumer\group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# c:\python\python37\lib\site-packages\kafka\consumer\group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# c:\python\python37\lib\site-packages\kafka\consumer\group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# c:\python\python37\lib\site-packages\kafka\client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# c:\python\python37\lib\site-packages\kafka\client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# c:\python\python37\lib\selectors.py in select(self, timeout)
#     321         ready = []
#     322         try:
# --> 323             r, w, _ = self._select(self._readers, self._writers, [], timeout)
#     324         except InterruptedError:
#     325             return ready
#
# c:\python\python37\lib\selectors.py in _select(self, r, w, _, timeout)
#     312     if sys.platform == 'win32':
#     313         def _select(self, r, w, _, timeout=None):
# --> 314             r, w, x = select.select(r, w, w, timeout)
#     315             return r, w + x, []
#     316     else:
#
# KeyboardInterrupt:

# %%
s3 = S3FileSystem()

# %%
for count,i in enumerate(consumer):
    with s3.open("s3://kafka-stockmarket-anubhav/stock_market_{}.json".format(count),'w') as file:
        json.dump(i.value,file)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# c:\python\python37\lib\site-packages\aiohttp\connector.py in _create_direct_connection(self, req, traces, timeout, client_error)
#    1151             #  across all connections.
# -> 1152             hosts = await asyncio.shield(host_resolved)
#    1153         except asyncio.CancelledError:
#
# c:\python\python37\lib\site-packages\aiohttp\connector.py in _resolve_host(self, host, port, traces)
#     873
# --> 874                 addrs = await self._resolver.resolve(host, port, family=self._family)
#     875                 if traces:
#
# c:\python\python37\lib\site-packages\aiohttp\resolver.py in resolve(self, hostname, port, family)
#      37             family=family,
# ---> 38             flags=socket.AI_ADDRCONFIG,
#      39         )
#
# c:\python\python37\lib\asyncio\base_events.py in getaddrinfo(self, host, port, family, type, proto, flags)
#     772         return await self.run_in_executor(
# --> 773             None, getaddr_func, host, port, family, type, proto, flags)
#     774
#
# c:\python\python37\lib\concurrent\futures\thread.py in run(self)
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#
# c:\python\python37\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11004] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# c:\python\python37\lib\site-packages\aiobotocore\httpsession.py in send(self, request)
#     214                 proxy=proxy_url,
# --> 215                 proxy_headers=proxy_headers,
#     216             )
#
# c:\python\python37\lib\site-packages\aiohttp\client.py in _request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, proxy_headers, trace_request_ctx, read_bufsize)
#     536                             conn = await self._connector.connect(
# --> 537                                 req, traces=traces, timeout=real_timeout
#     538                             )
#
# c:\python\python37\lib\site-packages\aiohttp\connector.py in connect(self, req, traces, timeout)
#     539             try:
# --> 540                 proto = await self._create_connection(req, traces, timeout)
#     541                 if self._closed:
#
# c:\python\python37\lib\site-packages\aiohttp\connector.py in _create_connection(self, req, traces, timeout)
#     900         else:
# --> 901             _, proto = await self._create_direct_connection(req, traces, timeout)
#     902
#
# c:\python\python37\lib\site-packages\aiohttp\connector.py in _create_direct_connection(self, req, traces, timeout, client_error)
#    1165             # it is problem of resolving proxy ip itself
# -> 1166             raise ClientConnectorError(req.connection_key, exc) from exc
#    1167
#
# ClientConnectorError: Cannot connect to host kafka-stockmarket-anubhav.s3.amazonaws.com:443 ssl:default [getaddrinfo failed]
#
# During handling of the above exception, another exception occurred:
#
# EndpointConnectionError                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15200\2024838612.py in <module>
#       1 for count,i in enumerate(consumer):
#       2     with s3.open("s3://kafka-stockmarket-anubhav/stock_market_{}.json".format(count),'w') as file:
# ----> 3         json.dump(i.value,file)
#
# c:\python\python37\lib\site-packages\fsspec\spec.py in close(self)
#    1768         else:
#    1769             if not self.forced:
# -> 1770                 self.flush(force=True)
#    1771
#    1772             if self.fs is not None:
#
# c:\python\python37\lib\site-packages\fsspec\spec.py in flush(self, force)
#    1639                 raise
#    1640
# -> 1641         if self._upload_chunk(final=force) is not False:
#    1642             self.offset += self.buffer.seek(0, 2)
#    1643             self.buffer = io.BytesIO()
#
# c:\python\python37\lib\site-packages\s3fs\core.py in _upload_chunk(self, final)
#    2206
#    2207         if self.autocommit and final:
# -> 2208             self.commit()
#    2209         return not final
#    2210
#
# c:\python\python37\lib\site-packages\s3fs\core.py in commit(self)
#    2227                     Body=data,
#    2228                     ACL=self.acl,
# -> 2229                     **self.kwargs,
#    2230                 )
#    2231             else:
#
# c:\python\python37\lib\site-packages\s3fs\core.py in _call_s3(self, method, *kwarglist, **kwargs)
#    2073
#    2074     def _call_s3(self, method, *kwarglist, **kwargs):
# -> 2075         return self.fs.call_s3(method, self.s3_additional_kwargs, *kwarglist, **kwargs)
#    2076
#    2077     def _initiate_upload(self):
#
# c:\python\python37\lib\site-packages\fsspec\asyn.py in wrapper(*args, **kwargs)
#     112     def wrapper(*args, **kwargs):
#     113         self = obj or args[0]
# --> 114         return sync(self.loop, func, *args, **kwargs)
#     115
#     116     return wrapper
#
# c:\python\python37\lib\site-packages\fsspec\asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      97         raise FSTimeoutError from return_result
#      98     elif isinstance(return_result, BaseException):
# ---> 99         raise return_result
#     100     else:
#     101         return return_result
#
# c:\python\python37\lib\site-packages\fsspec\asyn.py in _runner(event, coro, result, timeout)
#      52         coro = asyncio.wait_for(coro, timeout=timeout)
#      53     try:
# ---> 54         result[0] = await coro
#      55     except Exception as ex:
#      56         result[0] = ex
#
# c:\python\python37\lib\site-packages\s3fs\core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     338         additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist, **kwargs)
#     339         return await _error_wrapper(
# --> 340             method, kwargs=additional_kwargs, retries=self.retries
#     341         )
#     342
#
# c:\python\python37\lib\site-packages\s3fs\core.py in _error_wrapper(func, args, kwargs, retries)
#     137             err = e
#     138     err = translate_boto_error(err)
# --> 139     raise err
#     140
#     141
#
# c:\python\python37\lib\site-packages\s3fs\core.py in _error_wrapper(func, args, kwargs, retries)
#     110     for i in range(retries):
#     111         try:
# --> 112             return await func(*args, **kwargs)
#     113         except S3_RETRYABLE_ERRORS as e:
#     114             err = e
#
# c:\python\python37\lib\site-packages\aiobotocore\client.py in _make_api_call(self, operation_name, api_params)
#     340             apply_request_checksum(request_dict)
#     341             http, parsed_response = await self._make_request(
# --> 342                 operation_model, request_dict, request_context
#     343             )
#     344
#
# c:\python\python37\lib\site-packages\aiobotocore\client.py in _make_request(self, operation_model, request_dict, request_context)
#     365         try:
#     366             return await self._endpoint.make_request(
# --> 367                 operation_model, request_dict
#     368             )
#     369         except Exception as e:
#
# c:\python\python37\lib\site-packages\aiobotocore\endpoint.py in _send_request(self, request_dict, operation_model)
#     103             request_dict,
#     104             success_response,
# --> 105             exception,
#     106         ):
#     107             attempts += 1
#
# c:\python\python37\lib\site-packages\aiobotocore\endpoint.py in _needs_retry(self, attempts, operation_model, request_dict, response, caught_exception)
#     267             attempts=attempts,
#     268             caught_exception=caught_exception,
# --> 269             request_dict=request_dict,
#     270         )
#     271         handler_response = first_non_none_response(responses)
#
# c:\python\python37\lib\site-packages\aiobotocore\hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#      64
#      65             # Await the handler if its a coroutine.
# ---> 66             response = await resolve_awaitable(handler(**kwargs))
#      67             responses.append((handler, response))
#      68             if stop_on_response and response is not None:
#
# c:\python\python37\lib\site-packages\aiobotocore\_helpers.py in resolve_awaitable(obj)
#      13 async def resolve_awaitable(obj):
#      14     if inspect.isawaitable(obj):
# ---> 15         return await obj
#      16
#      17     return obj
#
# c:\python\python37\lib\site-packages\aiobotocore\retryhandler.py in _call(self, attempts, response, caught_exception, **kwargs)
#     105             checker_kwargs.update({'retries_context': retries_context})
#     106
# --> 107         if await resolve_awaitable(self._checker(**checker_kwargs)):
#     108             result = self._action(attempts=attempts)
#     109             logger.debug("Retry needed, action of: %s", result)
#
# c:\python\python37\lib\site-packages\aiobotocore\_helpers.py in resolve_awaitable(obj)
#      13 async def resolve_awaitable(obj):
#      14     if inspect.isawaitable(obj):
# ---> 15         return await obj
#      16
#      17     return obj
#
# c:\python\python37\lib\site-packages\aiobotocore\retryhandler.py in _call(self, attempt_number, response, caught_exception, retries_context)
#     125
#     126         should_retry = await self._should_retry(
# --> 127             attempt_number, response, caught_exception
#     128         )
#     129         if should_retry:
#
# c:\python\python37\lib\site-packages\aiobotocore\retryhandler.py in _should_retry(self, attempt_number, response, caught_exception)
#     164             # propagate if one has occurred.
#     165             return await resolve_awaitable(
# --> 166                 self._checker(attempt_number, response, caught_exception)
#     167             )
#     168
#
# c:\python\python37\lib\site-packages\aiobotocore\_helpers.py in resolve_awaitable(obj)
#      13 async def resolve_awaitable(obj):
#      14     if inspect.isawaitable(obj):
# ---> 15         return await obj
#      16
#      17     return obj
#
# c:\python\python37\lib\site-packages\aiobotocore\retryhandler.py in _call(self, attempt_number, response, caught_exception)
#     172         for checker in self._checkers:
#     173             checker_response = await resolve_awaitable(
# --> 174                 checker(attempt_number, response, caught_exception)
#     175             )
#     176             if checker_response:
#
# c:\python\python37\lib\site-packages\botocore\retryhandler.py in __call__(self, attempt_number, response, caught_exception)
#     246         elif caught_exception is not None:
#     247             return self._check_caught_exception(
# --> 248                 attempt_number, caught_exception
#     249             )
#     250         else:
#
# c:\python\python37\lib\site-packages\botocore\retryhandler.py in _check_caught_exception(self, attempt_number, caught_exception)
#     414         # the MaxAttemptsDecorator is not interested in retrying the exception
#     415         # then this exception just propogates out past the retry code.
# --> 416         raise caught_exception
#
# c:\python\python37\lib\site-packages\aiobotocore\endpoint.py in _do_get_response(self, request, operation_model, context)
#     179             http_response = first_non_none_response(responses)
#     180             if http_response is None:
# --> 181                 http_response = await self._send(request)
#     182         except HTTPClientError as e:
#     183             return (None, e)
#
# c:\python\python37\lib\site-packages\aiobotocore\endpoint.py in _send(self, request)
#     283
#     284     async def _send(self, request):
# --> 285         return await self.http_session.send(request)
#     286
#     287
#
# c:\python\python37\lib\site-packages\aiobotocore\httpsession.py in send(self, request)
#     251             socket.gaierror,
#     252         ) as e:
# --> 253             raise EndpointConnectionError(endpoint_url=request.url, error=e)
#     254         except asyncio.TimeoutError as e:
#     255             raise ReadTimeoutError(endpoint_url=request.url, error=e)
#
# EndpointConnectionError: Could not connect to the endpoint URL: "https://kafka-stockmarket-anubhav.s3.amazonaws.com/stock_market_2522.json"
